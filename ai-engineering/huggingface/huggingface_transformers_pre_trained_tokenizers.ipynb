# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
model = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model)

# %%
text = "Hugging Face is creating a tool that democratizes AI."

# %%
encoded_input = tokenizer(text, return_tensors="pt")
print(encoded_input)

# %%
tokens = tokenizer.tokenize(text)
print(tokens)

# %%
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(token_ids)

# %%
decoded_ids = tokenizer.decode(token_ids)
print(decoded_ids)

# %%
tokenizer.decode(101)

# %%
tokenizer.decode(102)

# %%
model2 = "xlnet-base-cased"

# %%
toeknizer2 = AutoTokenizer.from_pretrained(model2)

# %%
encoded_input2 = toeknizer2(text, return_tensors="pt")
print(encoded_input2)

# %%
tokens = toeknizer2.tokenize(text)
print(tokens)

# %%
token_ids = toeknizer2.convert_tokens_to_ids(tokens)
print(token_ids)

# %%
toeknizer2.decode(4)

# %%
toeknizer2.decode(3)
